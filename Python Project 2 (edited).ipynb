# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %% [markdown]
# Problem Statment: Which gender is most likely to have diabetes?

# %%
df.head(1000)
# Out:
#      encounter_id  patient_nbr             race  gender      age weight  \
# 0         2278392      8222157        Caucasian  Female   [0-10)      ?
# 1          149190     55629189        Caucasian  Female  [10-20)      ?
# 2           64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3          500364     82442376        Caucasian    Male  [30-40)      ?
# 4           16680     42519267        Caucasian    Male  [40-50)      ?
# ..            ...          ...              ...     ...      ...    ...
# 995       7497384      3616155        Caucasian    Male  [70-80)      ?
# 996       7500936      1070622        Caucasian    Male   [0-10)      ?
# 997       7501614     23165379        Caucasian    Male  [60-70)      ?
# 998       7502424      4792239        Caucasian  Female  [70-80)      ?
# 999       7555146      2766582        Caucasian    Male  [50-60)      ?
#
#      admission_type_id  discharge_disposition_id  admission_source_id  \
# ...

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.tail(1000)
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 100766     430751654    103310649        Caucasian    Male  [70-80)      ?
# 100767     430753394     80763894        Caucasian    Male  [70-80)      ?
# 100768     430753628     57277548        Caucasian    Male  [80-90)      ?
# 100769     430762784     46020915        Caucasian    Male  [60-70)      ?
# 100770     430773518     39610080        Caucasian  Female  [80-90)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %% [markdown]
# Trying to view all the columns since I cant see them on the table above.

# %%
print("All columns in the dataset:")
print(df.columns)
# Out:
# All columns in the dataset:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.head(50)
# Out:
#     encounter_id  patient_nbr             race  gender       age weight  \
# 0        2278392      8222157        Caucasian  Female    [0-10)      ?
# 1         149190     55629189        Caucasian  Female   [10-20)      ?
# 2          64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3         500364     82442376        Caucasian    Male   [30-40)      ?
# 4          16680     42519267        Caucasian    Male   [40-50)      ?
# 5          35754     82637451        Caucasian    Male   [50-60)      ?
# 6          55842     84259809        Caucasian    Male   [60-70)      ?
# 7          63768    114882984        Caucasian    Male   [70-80)      ?
# 8          12522     48330783        Caucasian  Female   [80-90)      ?
# 9          15738     63555939        Caucasian  Female  [90-100)      ?
# 10         28236     89869032  AfricanAmerican  Female   [40-50)      ?
# 11         36900     77391171  AfricanAmerican    Male   [60-70)      ?
# ...

# %% [markdown]
# Trying to figure out if the columns below have any values.Most of them have eithier a '?' or "None" written next to them at first glance. This confused me because it said all of them were not unique which implies they all say '?' or 'None' which does not make sense since this is a Diabetes Data set and it should include A1Cresults data at most. Not sure if i am interperting this wrong.

# %%
column_name = 'A1Cresult'


if df[column_name].nunique() == len(df):
    print(f"The {column_name} column is unique.")
else:
    print(f"The {column_name} column is not unique.")
# Out:
# The A1Cresult column is not unique.

# %%
column_name = 'weight'


if df[column_name].nunique() == len(df):
    print(f"The {column_name} column is unique.")
else:
    print(f"The {column_name} column is not unique.")
# Out:
# The weight column is not unique.

# %%
column_name = 'payer_code'


if df[column_name].nunique() == len(df):
    print(f"The {column_name} column is unique.")
else:
    print(f"The {column_name} column is not unique.")
# Out:
# The payer_code column is not unique.

# %%
column_name = 'insulin'


if df[column_name].nunique() == len(df):
    print(f"The {column_name} column is unique.")
else:
    print(f"The {column_name} column is not unique.")
# Out:
# The insulin column is not unique.

# %%
drop_cols = ['encounter_id', 'patient_nbr','race','age', 'weight',
       'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
       'time_in_hospital', 'payer_code', 'medical_specialty',
       'num_lab_procedures', 'num_procedures', 'num_medications',
       'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
       'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum',
       'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
       'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
       'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
       'tolazamide', 'examide', 'citoglipton', 'insulin',
       'glyburide-metformin', 'glipizide-metformin',
       'glimepiride-pioglitazone', 'metformin-rosiglitazone',
       'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted']

df.drop(drop_cols, inplace = True, axis=1)

# %%
df.head(50)
# Out:
#     gender A1Cresult
# 0   Female      None
# 1   Female      None
# 2   Female      None
# 3     Male      None
# 4     Male      None
# 5     Male      None
# 6     Male      None
# 7     Male      None
# 8   Female      None
# 9   Female      None
# 10  Female      None
# 11    Male      None
# 12  Female      None
# 13    Male      None
# 14  Female      None
# 15    Male      None
# 16    Male      None
# 17  Female      None
# 18    Male      None
# 19    Male      None
# 20  Female      None
# 21    Male      None
# 22  Female      None
# 23  Female      None
# 24  Female      None
# 25  Female      None
# 26    Male        >7
# 27  Female      None
# 28    Male      None
# 29  Female      None
# 30  Female      None
# 31    Male      None
# 32  Female      None
# 33    Male      None
# 34  Female      None
# 35  Female      None
# 36  Female      None
# 37  Female      None
# 38    Male      None
# 39    Male      None
# 40  Female      None
# 41    Male      None
# ...

# %% [markdown]
# Coudn't figure it out so decided to drop all values with '?' or 'None' and patients who did not have diabetes 'Norm'

# %%
import numpy as np

df.replace(['?', 'None','Norm'], np.nan, inplace=True)

df.dropna(inplace=True)

# %%
I WAS RIGHT!! 8)

# %%
df.head(60)
# Out:
#      gender A1Cresult
# 26     Male        >7
# 74   Female        >7
# 98   Female        >8
# 117  Female        >7
# 123  Female        >8
# 125  Female        >8
# 131  Female        >8
# 132  Female        >8
# 136  Female        >8
# 141  Female        >8
# 148  Female        >7
# 159  Female        >8
# 166  Female        >8
# 180    Male        >8
# 182    Male        >8
# 192  Female        >8
# 197  Female        >8
# 203  Female        >7
# 204    Male        >8
# 213    Male        >8
# 216  Female        >8
# 220    Male        >8
# 225  Female        >8
# 228  Female        >7
# 234    Male        >8
# 243  Female        >8
# 249  Female        >8
# 258    Male        >8
# 259    Male        >7
# 268  Female        >8
# 269  Female        >8
# 270  Female        >8
# 274    Male        >8
# 277  Female        >8
# 280  Female        >7
# 281    Male        >8
# 283    Male        >8
# 293  Female        >8
# 294  Female        >8
# 323    Male        >8
# ...

# %%
import seaborn as sns

# %%
df2 = df[['gender', 'A1Cresult']]

# %%
df2.head()
# Out:
#      gender A1Cresult
# 26     Male        >7
# 74   Female        >7
# 98   Female        >8
# 117  Female        >7
# 123  Female        >8

# %%
sns.set(style="whitegrid")


plt.figure(figsize=(10, 6))
ax = sns.countplot(x='gender', hue='A1Cresult', data=df2, palette=['lightblue', 'pink'])


for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.title('A1Cresult Comparison by Gender')
plt.xlabel('Gender')
plt.ylabel('Count of Patients with Diabetes')
plt.legend(title='A1Cresult', loc='upper right')
plt.show()

# %% [markdown]
# A normal A1C level is below 5.7%, a level of 5.7% to 6.4% indicates prediabetes, and a level of 6.5% or more indicates diabetes. Within the 5.7% to 6.4% prediabetes range, the higher your A1C, the greater your risk is for developing type 2 diabetes.
#
# In conclusion Women were slightly more likely to have diabetes according to this data set.
