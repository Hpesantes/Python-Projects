# %% [markdown]
# <a href="https://colab.research.google.com/github/Hpesantes/SQL-Projects/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df=pd.read_csv ('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/faithful.csv')
df.head(10)
df.tail(15)
df.count()
df.min()
df.max()
df.mean()
df['eruptions']
df['eruptions'].mean()
df['waiting']
df['waiting'].mean()
# Out:
# 70.8970588235294

# %%
import matplotlib.pyplot as plot
# %matplotlib inline

df.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'eruptions'}>],
#        [<Axes: title={'center': 'waiting'}>, <Axes: >]], dtype=object)

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='scatter', x='waiting',y='eruptions')
# Out:
# <Axes: xlabel='waiting', ylabel='eruptions'>

# %%
df.groupby(['waiting'])['waiting'].count().sort_values(ascending=False)
df{df['eruptions']=='3.333']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-4c858ac8cc3c> in <cell line: 2>()
#       1 df.groupby(['waiting'])['waiting'].count().sort_values(ascending=False)
# ----> 2 df[['Unamed: 0','eruptions']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
# ...

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv')
# Out:
# <ipython-input-64-f2dc0caeb3f4>:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv')
